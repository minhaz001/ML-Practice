# %%
df = sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.shape
# Out:
# (150, 5)

# %%
df.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Univariate Analysis

# %%
## Separating each species
df_setosa=df.loc[df['species']=='setosa']

# %%
df_virginica=df.loc[df['species']=='virginica']
df_versicolor=df.loc[df['species']=='versicolor']

# %%
plt.plot(df_setosa['sepal_length'],np.zeros_like(df_setosa['sepal_length']),'o')
plt.show()

# %%
plt.plot(df_setosa['sepal_length'],np.zeros_like(df_setosa['sepal_length']),'o', color='m')
plt.plot(df_versicolor['sepal_length'],np.zeros_like(df_versicolor['sepal_length']),'o', color='y')
plt.plot(df_virginica['sepal_length'],np.zeros_like(df_virginica['sepal_length']),'o',color='k')
plt.xlabel('sepal length')
plt.show()

# %% [markdown]
# ## Bivariate Analysis

# %%
sns.FacetGrid(df,hue='species', size= 6).map(plt.scatter,'petal_length', 'sepal_width').add_legend()
plt.show()
# Out:
# C:\Users\MinhazPC\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.jointplot(x='petal_length', y= 'sepal_width', data= df, kind='scatter', hue= 'species')

# %% [markdown]
# ## Multivariate Analysis

# %%
sns.pairplot(df, hue='species', size=3)
# Out:
# C:\Users\MinhazPC\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
